# %%
from diffusers import DiffusionPipeline
# Out:
# c:\Users\Xiyao\projects\ddpm-alzheimer-mri-128\.venv\Lib\site-packages\diffusers\models\transformers\transformer_2d.py:34: FutureWarning: `Transformer2DModelOutput` is deprecated and will be removed in version 1.0.0. Importing `Transformer2DModelOutput` from `diffusers.models.transformer_2d` is deprecated and this will be removed in a future version. Please use `from diffusers.models.modeling_outputs import Transformer2DModelOutput`, instead.
#   deprecate("Transformer2DModelOutput", "1.0.0", deprecation_message)

# %%
pipeline = DiffusionPipeline.from_pretrained("xiyaozhuang/ddpm-alzheimer-mri-128")
# Out:
# Loading pipeline components...:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
pipeline.to("cuda")
# Out:
# DDPMPipeline {
#   "_class_name": "DDPMPipeline",
#   "_diffusers_version": "0.28.2",
#   "_name_or_path": "xiyaozhuang/ddpm-alzheimer-mri-128",
#   "scheduler": [
#     "diffusers",
#     "DDPMScheduler"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DModel"
#   ]
# }

# %%
image = pipeline().images[0]
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# c:\Users\Xiyao\projects\ddpm-alzheimer-mri-128\.venv\Lib\site-packages\diffusers\models\attention_processor.py:1416: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   hidden_states = F.scaled_dot_product_attention(

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
